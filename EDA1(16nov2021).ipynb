# %%
# !pip install sweetviz

# %%
import pandas as pd
import numpy as np
import sweetviz as sv

# %%
df_1=pd.read_csv("E:\\notebooks file\\data_clean.csv")

# %%
df_1.shape
# Out:
# (158, 10)

# %%
df_1.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
df2=df_1.iloc[:,1:]

# %%
df2
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df=df2.copy()

# %%
df
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df['Month']=pd.to_numeric(df['Month'],errors='coerce')

# %%
df['Temp C']=pd.to_numeric(df['Temp C'],errors='coerce')

# %%
df['Weather']=df['Weather'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(5), int64(3)
# memory usage: 10.3 KB

# %%
df[df.duplicated()].shape
# Out:
# (1, 9)

# %%
df[df.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
df_cl1=df.drop_duplicates()

# %%
df_cl1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    68.0    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [157 rows x 9 columns]

# %%
df_cl2=df_cl1.drop('Temp C',axis=1)

# %%
df_cl3=df_cl2.rename({'Solar.R':'Solar'},axis=1)

# %%
df_cl3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df_cl3.Ozone)
# Out:
# (array([28., 36., 21.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
df_cl3.boxplot(column=['Ozone'])
# Out:
# <Axes: >

# %%
df_cl3['Ozone'].hist()
# Out:
# <Axes: >

# %%
plt.hist(df_cl3.Solar)
# Out:
# (array([13., 10., 12., 11., 11., 20., 15., 30., 19.,  9.]),
#  array([  7. ,  39.7,  72.4, 105.1, 137.8, 170.5, 203.2, 235.9, 268.6,
#         301.3, 334. ]),
#  <BarContainer object of 10 artists>)

# %%
df_cl3.boxplot(column=['Solar'])
# Out:
# <Axes: >

# %%
plt.hist(df_cl3.Wind)
# Out:
# (array([ 4.,  9., 21., 39., 30., 22., 22.,  7.,  1.,  2.]),
#  array([ 1.7,  3.6,  5.5,  7.4,  9.3, 11.2, 13.1, 15. , 16.9, 18.8, 20.7]),
#  <BarContainer object of 10 artists>)

# %%
df_cl3.boxplot(column=['Wind'])
# Out:
# <Axes: >

# %%
plt.hist(df_cl3.Temp)
# Out:
# (array([ 8.,  8., 14., 11., 23., 25., 29., 20., 12.,  7.]),
#  array([56. , 60.1, 64.2, 68.3, 72.4, 76.5, 80.6, 84.7, 88.8, 92.9, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
df_cl3.boxplot(column=['Temp'])
# Out:
# <Axes: >

# %%
df_cl3['Ozone'].describe()
# Out:
# count    119.000000
# mean      41.815126
# std       32.659249
# min        1.000000
# 25%       18.000000
# 50%       31.000000
# 75%       62.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
df_cl3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
df_cl3['Weather'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Weather'>

# %%
##import seaborn as sns
##cols=df_cl3.columns
#colours=['#,000099','#ffff00']
#sns.heatmap(df_cl3[cols].isnull(),
            #cmap=sns.color_palette(colours))

# %%
df_cl3[df_cl3.isnull().any(axis=1)].head()
# Out:
#     Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 4     NaN    NaN  14.3    5.0    5  2010    56       S
# 5    28.0    NaN  14.9    5.0    6  2010    66       C
# 9     NaN  194.0   8.6    5.0   10  2010    69       S
# 10    7.0    NaN   6.9    5.0   11  2010    74       C
# 23   32.0   92.0  12.0    NaN   24  2010    61       C

# %%
df_cl3[df_cl3.isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# 5     28.0    NaN  14.9    5.0    6  2010    66       C
# 9      NaN  194.0   8.6    5.0   10  2010    69       S
# 10     7.0    NaN   6.9    5.0   11  2010    74       C
# 23    32.0   92.0  12.0    NaN   24  2010    61       C
# 24     NaN   66.0  16.6    5.0   25  2010    57      PS
# 25     NaN  266.0  14.9    5.0   26  2010    58       C
# 26     NaN    NaN   8.0    5.0   27  2010    57      PS
# 31     NaN  286.0   8.6    6.0    1  2010    78       S
# 32     NaN  287.0   9.7    6.0    2  2010    74       C
# 33     NaN  242.0  16.1    6.0    3  2010    67      PS
# 34     NaN  186.0   9.2    6.0    4  2010    84       C
# 35     NaN  220.0   8.6    6.0    5  2010    85      PS
# 36     NaN  264.0  14.3    6.0    6  2010    79       C
# 38     NaN  273.0   6.9    6.0    8  2010    87       S
# 41     NaN  259.0  10.9    6.0   11  2010    93       C
# ...

# %%
df_cl3.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
mean=df_cl3['Ozone'].mean()

# %%
df_cl3['Ozone'].fillna(mean)
# Out:
# 0      41.000000
# 1      36.000000
# 2      12.000000
# 3      18.000000
# 4      41.815126
#          ...
# 152    20.000000
# 153    41.000000
# 154    30.000000
# 155    41.815126
# 157    18.000000
# Name: Ozone, Length: 157, dtype: float64

# %%
df_cl3['Ozone']=df_cl3['Ozone'].fillna(mean)

# %%
df_cl3['Ozone']
# Out:
# 0      41.000000
# 1      36.000000
# 2      12.000000
# 3      18.000000
# 4      41.815126
#          ...
# 152    20.000000
# 153    41.000000
# 154    30.000000
# 155    41.815126
# 157    18.000000
# Name: Ozone, Length: 157, dtype: float64

# %%
df_cl3.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
mean=df_cl3['Solar'].mean()

# %%
mean
# Out:
# 185.36666666666667

# %%
df_cl3['Solar']=df_cl3['Solar'].fillna(mean)

# %%
df_cl3
# Out:
#          Ozone       Solar  Wind  Month  Day  Year  Temp Weather
# 0    41.000000  190.000000   7.4    5.0    1  2010    67       S
# 1    36.000000  118.000000   8.0    5.0    2  2010    72       C
# 2    12.000000  149.000000  12.6    5.0    3  2010    74      PS
# 3    18.000000  313.000000  11.5    5.0    4  2010    62       S
# 4    41.815126  185.366667  14.3    5.0    5  2010    56       S
# ..         ...         ...   ...    ...  ...   ...   ...     ...
# 152  20.000000  223.000000  11.5    9.0   30  2010    68       S
# 153  41.000000  190.000000   7.4    5.0    1  2010    67       C
# 154  30.000000  193.000000   6.9    9.0   26  2010    70      PS
# 155  41.815126  145.000000  13.2    9.0   27  2010    77       S
# 157  18.000000  131.000000   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
obj_w=df_cl3['Weather']

# %%
df_cl4=df_cl3.rename({'Weather':'Weather_t'},axis=1)

# %%
df_cl4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ozone      157 non-null    float64
#  1   Solar      157 non-null    float64
#  2   Wind       157 non-null    float64
#  3   Month      156 non-null    float64
#  4   Day        157 non-null    int64
#  5   Year       157 non-null    int64
#  6   Temp       157 non-null    int64
#  7   Weather_t  154 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 10.1 KB

# %%
df_cl5=df_cl4.drop('Weather_t',axis=1)

# %%
df_cl5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ozone   157 non-null    float64
#  1   Solar   157 non-null    float64
#  2   Wind    157 non-null    float64
#  3   Month   156 non-null    float64
#  4   Day     157 non-null    int64
#  5   Year    157 non-null    int64
#  6   Temp    157 non-null    int64
# dtypes: float64(4), int64(3)
# memory usage: 9.8 KB

# %%
obj_w
# Out:
# 0       S
# 1       C
# 2      PS
# 3       S
# 4       S
#        ..
# 152     S
# 153     C
# 154    PS
# 155     S
# 157     C
# Name: Weather, Length: 157, dtype: category
# Categories (3, object): ['C', 'PS', 'S']

# %%
obj_w.isnull().sum()
# Out:
# 3

# %%
obj_w=obj_w.fillna(obj_w.mode().iloc[0])

# %%
obj_w.isnull().sum()
# Out:
# 0

# %%
df_cl6=pd.concat([df_cl5,obj_w],axis=1)

# %%
df_cl6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    157 non-null    float64
#  1   Solar    157 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  157 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 10.1 KB

# %%
df_cl6.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
df_cl6.shape
# Out:
# (157, 8)

# %%
df_cl6=df_cl6.dropna()

# %%
df_cl6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 156 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    156 non-null    float64
#  1   Solar    156 non-null    float64
#  2   Wind     156 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      156 non-null    int64
#  5   Year     156 non-null    int64
#  6   Temp     156 non-null    int64
#  7   Weather  156 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 10.0 KB

# %%
import seaborn as sns

# %%
sns.pairplot(df_cl6)
# Out:
# C:\Users\Server\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_cl5.corr()
# Out:
#           Ozone     Solar      Wind     Month       Day  Year      Temp
# Ozone  1.000000  0.304559 -0.520004  0.132860 -0.021916   NaN  0.606500
# Solar  0.304559  1.000000 -0.055874 -0.090902 -0.151007   NaN  0.260677
# Wind  -0.520004 -0.055874  1.000000 -0.166216  0.029900   NaN -0.441228
# Month  0.132860 -0.090902 -0.166216  1.000000  0.050055   NaN  0.398516
# Day   -0.021916 -0.151007  0.029900  0.050055  1.000000   NaN -0.122787
# Year        NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp   0.606500  0.260677 -0.441228  0.398516 -0.122787   NaN  1.000000

# %%
df_cl7=pd.get_dummies(df2,columns=['Weather'])

# %%
df_cl7
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp  Weather_C  \
# 0     41.0    190.0   7.4     67     5    1  2010    67      False
# 1     36.0    118.0   8.0     72     5    2  2010    72       True
# 2     12.0    149.0  12.6     74     5    3  2010    74      False
# 3     18.0    313.0  11.5     62     5    4  2010    62      False
# 4      NaN      NaN  14.3     56     5    5  2010    56      False
# ..     ...      ...   ...    ...   ...  ...   ...   ...        ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       True
# 154   30.0    193.0   6.9     70     9   26  2010    70      False
# 155    NaN    145.0  13.2     77     9   27  2010    77      False
# 156   14.0    191.0  14.3     75     9   28  2010    75      False
# 157   18.0    131.0   8.0     76     9   29  2010    76       True
#
#      Weather_PS  Weather_S
# 0         False       True
# 1         False      False
# 2          True      False
# 3         False       True
# ...

# %% [markdown]
# To convert true nd false into 1,0 use :--1)df_cl7['Weather_C'].map({True:1,False:0})
#                                          2)df_cl7['Weather_C'].replace({True:1,False:0})
#                                          3)df_cl7['Weather_C'].astype(int)

# %%
df_cl7['Weather_C']=df_cl7['Weather_C'].astype(int)

# %%
df_cl7
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp  Weather_C  \
# 0     41.0    190.0   7.4     67     5    1  2010    67          0
# 1     36.0    118.0   8.0     72     5    2  2010    72          1
# 2     12.0    149.0  12.6     74     5    3  2010    74          0
# 3     18.0    313.0  11.5     62     5    4  2010    62          0
# 4      NaN      NaN  14.3     56     5    5  2010    56          0
# ..     ...      ...   ...    ...   ...  ...   ...   ...        ...
# 153   41.0    190.0   7.4     67     5    1  2010    67          1
# 154   30.0    193.0   6.9     70     9   26  2010    70          0
# 155    NaN    145.0  13.2     77     9   27  2010    77          0
# 156   14.0    191.0  14.3     75     9   28  2010    75          0
# 157   18.0    131.0   8.0     76     9   29  2010    76          1
#
#      Weather_PS  Weather_S
# 0         False       True
# 1         False      False
# 2          True      False
# 3         False       True
# ...

# %%
df_cl7['Weather_PS']=df_cl7['Weather_PS'].astype(int)

# %%
df_cl7
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp  Weather_C  \
# 0     41.0    190.0   7.4     67     5    1  2010    67          0
# 1     36.0    118.0   8.0     72     5    2  2010    72          1
# 2     12.0    149.0  12.6     74     5    3  2010    74          0
# 3     18.0    313.0  11.5     62     5    4  2010    62          0
# 4      NaN      NaN  14.3     56     5    5  2010    56          0
# ..     ...      ...   ...    ...   ...  ...   ...   ...        ...
# 153   41.0    190.0   7.4     67     5    1  2010    67          1
# 154   30.0    193.0   6.9     70     9   26  2010    70          0
# 155    NaN    145.0  13.2     77     9   27  2010    77          0
# 156   14.0    191.0  14.3     75     9   28  2010    75          0
# 157   18.0    131.0   8.0     76     9   29  2010    76          1
#
#      Weather_PS  Weather_S
# 0             0       True
# 1             0      False
# 2             1      False
# 3             0       True
# ...

# %%
df_cl7['Weather_S']=df_cl7['Weather_S'].astype(int)

# %%
df_cl7
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp  Weather_C  \
# 0     41.0    190.0   7.4     67     5    1  2010    67          0
# 1     36.0    118.0   8.0     72     5    2  2010    72          1
# 2     12.0    149.0  12.6     74     5    3  2010    74          0
# 3     18.0    313.0  11.5     62     5    4  2010    62          0
# 4      NaN      NaN  14.3     56     5    5  2010    56          0
# ..     ...      ...   ...    ...   ...  ...   ...   ...        ...
# 153   41.0    190.0   7.4     67     5    1  2010    67          1
# 154   30.0    193.0   6.9     70     9   26  2010    70          0
# 155    NaN    145.0  13.2     77     9   27  2010    77          0
# 156   14.0    191.0  14.3     75     9   28  2010    75          0
# 157   18.0    131.0   8.0     76     9   29  2010    76          1
#
#      Weather_PS  Weather_S
# 0             0          1
# 1             0          0
# 2             1          0
# 3             0          1
# ...

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
df_cl8=df_cl7.values

# %%
df_cl8
# Out:
# array([[41.0, 190.0, 7.4, ..., 0, 0, 1],
#        [36.0, 118.0, 8.0, ..., 1, 0, 0],
#        [12.0, 149.0, 12.6, ..., 0, 1, 0],
#        ...,
#        [nan, 145.0, 13.2, ..., 0, 0, 1],
#        [14.0, 191.0, 14.3, ..., 0, 0, 1],
#        [18.0, 131.0, 8.0, ..., 1, 0, 0]], dtype=object)

# %%
array=df_cl6.values
Scaler=MinMaxScaler(feature_range=(0,1))
rescaledx=Scaler.fit_transform(array[:,0:5])

# %%
rescaledx
# Out:
# array([[0.23952096, 0.55963303, 0.3       , 0.        , 0.        ],
#        [0.20958084, 0.33944954, 0.33157895, 0.        , 0.03333333],
#        [0.06586826, 0.43425076, 0.57368421, 0.        , 0.06666667],
#        [0.10179641, 0.93577982, 0.51578947, 0.        , 0.1       ],
#        [0.24440195, 0.54546381, 0.66315789, 0.        , 0.13333333],
#        [0.16167665, 0.54546381, 0.69473684, 0.        , 0.16666667],
#        [0.13173653, 0.89296636, 0.36315789, 0.        , 0.2       ],
#        [0.10778443, 0.28134557, 0.63684211, 0.        , 0.23333333],
#        [0.04191617, 0.03669725, 0.96842105, 0.        , 0.26666667],
#        [0.24440195, 0.57186544, 0.36315789, 0.        , 0.3       ],
#        [0.03592814, 0.54546381, 0.27368421, 0.        , 0.33333333],
#        [0.08982036, 0.76146789, 0.42105263, 0.        , 0.36666667],
#        [0.05988024, 0.86544343, 0.39473684, 0.        , 0.4       ],
#        [0.07784431, 0.81651376, 0.48421053, 0.        , 0.43333333],
# ...

# %%
set_printoptions(precision=2)
print(rescaledx[0:5,:])
# Out:
# [[0.24 0.56 0.3  0.   0.  ]
#  [0.21 0.34 0.33 0.   0.03]
#  [0.07 0.43 0.57 0.   0.07]
#  [0.1  0.94 0.52 0.   0.1 ]
#  [0.24 0.55 0.66 0.   0.13]]

# %%
from sklearn.preprocessing import StandardScaler

# %%
array=df_cl6.values
scaler=StandardScaler()
rescaledx=scaler.fit_transform(array[:,0:5])
set_printoptions(precision=2)
print(rescaledx[0:5,:])
# Out:
# [[-0.03  0.05 -0.72 -1.43 -1.66]
#  [-0.21 -0.78 -0.55 -1.43 -1.55]
#  [-1.05 -0.43  0.77 -1.43 -1.44]
#  [-0.84  1.47  0.45 -1.43 -1.33]
#  [-0.   -0.01  1.25 -1.43 -1.22]]

# %%
rescaledx
# Out:
# array([[-3.09e-02,  4.66e-02, -7.19e-01, -1.43e+00, -1.66e+00],
#        [-2.07e-01, -7.84e-01, -5.47e-01, -1.43e+00, -1.55e+00],
#        [-1.05e+00, -4.26e-01,  7.66e-01, -1.43e+00, -1.44e+00],
#        [-8.41e-01,  1.47e+00,  4.52e-01, -1.43e+00, -1.33e+00],
#        [-2.22e-03, -6.91e-03,  1.25e+00, -1.43e+00, -1.22e+00],
#        [-4.89e-01, -6.91e-03,  1.42e+00, -1.43e+00, -1.10e+00],
#        [-6.65e-01,  1.30e+00, -3.76e-01, -1.43e+00, -9.92e-01],
#        [-8.06e-01, -1.00e+00,  1.11e+00, -1.43e+00, -8.80e-01],
#        [-1.19e+00, -1.93e+00,  2.91e+00, -1.43e+00, -7.68e-01],
#        [-2.22e-03,  9.27e-02, -3.76e-01, -1.43e+00, -6.57e-01],
#        [-1.23e+00, -6.91e-03, -8.62e-01, -1.43e+00, -5.45e-01],
#        [-9.11e-01,  8.08e-01, -6.19e-02, -1.43e+00, -4.33e-01],
#        [-1.09e+00,  1.20e+00, -2.05e-01, -1.43e+00, -3.22e-01],
#        [-9.82e-01,  1.02e+00,  2.81e-01, -1.43e+00, -2.10e-01],
#        [-8.41e-01, -1.40e+00,  9.38e-01, -1.43e+00, -9.81e-02],
# ...

# %%
Sweet_report=sv.analyze(df)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
Sweet_report.show_html('Weather_report.html')
# Out:
# Report Weather_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
